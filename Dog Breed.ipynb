# %%
import sklearn
import sklearn.datasets
import sklearn.tree
import matplotlib.pyplot as plt
import sklearn.linear_model
import pandas as pd
import numpy as np
import sklearn.ensemble
import pylab as pl

# %%
from resizeimage import resizeimage

# %%
import scipy.misc as smp

# %%
import os

# %%
from PIL import Image

# %%
root_dir = '/Users/hardiktaneja/Desktop/dog_breed/train'
filepaths1 = [os.path.join(root_dir,f) for f in os.listdir(root_dir)]

# %%
# Out:
# ['/Users/hardiktaneja/Desktop/dog_breed/train/000bec180eb18c7604dcecc8fe0dba07.jpg',
#  '/Users/hardiktaneja/Desktop/dog_breed/train/001513dfcb2ffafc82cccf4d8bbaba97.jpg',
#  '/Users/hardiktaneja/Desktop/dog_breed/train/001cdf01b096e06d78e9e5112d419397.jpg',
#  '/Users/hardiktaneja/Desktop/dog_breed/train/00214f311d5d2247d5dfe4fe24b2303d.jpg',
#  '/Users/hardiktaneja/Desktop/dog_breed/train/0021f9ceb3235effd7fcde7f7538ed62.jpg',
#  '/Users/hardiktaneja/Desktop/dog_breed/train/002211c81b498ef88e1b40b9abf84e1d.jpg',
#  '/Users/hardiktaneja/Desktop/dog_breed/train/00290d3e1fdd27226ba27a8ce248ce85.jpg',
#  '/Users/hardiktaneja/Desktop/dog_breed/train/002a283a315af96eaea0e28e7163b21b.jpg',
#  '/Users/hardiktaneja/Desktop/dog_breed/train/003df8b8a8b05244b1d920bb6cf451f9.jpg',
#  '/Users/hardiktaneja/Desktop/dog_breed/train/0042188c895a2f14ef64a918ed9c7b64.jpg',
#  '/Users/hardiktaneja/Desktop/dog_breed/train/004396df1acd0f1247b740ca2b14616e.jpg',
# ...

# %%
imgarr=[]
targetarr=[]
for j in filepaths1:
    root_dir = j
    if(j == '/Users/hardiktaneja/Desktop/dog_breed/train/.DS_Store'):
        continue
    
    img = Image.open(j)
    h = np.array(img)
#     s = h.shape
    imgarr.append(h)
#     m =int(j.split('/')[len(j.split('/'))-1].split('_')[1])
#     targetarr.append(m)

# %%
imgarrrrrrr = np.array(imgarr)

# %%
len(imgarrrrrrr)
# Out:
# 10222

# %%
imgarrrrrrr
# Out:
# array([ array([[[109,  46,   0],
#         [153,  91,  40],
#         [180, 120,  68],
#         ...,
#         [176, 144,  71],
#         [189, 157,  84],
#         [214, 182, 109]],
#
#        [[153,  92,  47],
#         [179, 121,  75],
#         [167, 111,  64],
#         ...,
#         [167, 135,  58],
#         [171, 139,  62],
#         [188, 156,  79]],
#
#        [[152,  97,  56],
#         [189, 136,  94],
#         [164, 113,  70],
#         ...,
#         [200, 168,  81],
#         [194, 162,  75],
#         [200, 168,  81]],
#
#        ...,
#        [[189, 122,  69],
#         [186, 119,  66],
#         [183, 116,  63],
#         ...,
#         [213, 160, 108],
#         [212, 159, 107],
#         [209, 156, 104]],
#
#        [[186, 119,  66],
#         [184, 117,  64],
#         [183, 116,  63],
#         ...,
#         [197, 145,  88],
#         [199, 147,  90],
#         [199, 147,  90]],
#
#        [[182, 115,  62],
#         [181, 114,  61],
# ...

# %%
len(imgarr)
# Out:
# 10222

# %%
len(set(imgarr))
# Out:
# 2656

# %%
max(set(imgarr))
# Out:
# (2562, 2388, 3)

# %%
url= '/Users/hardiktaneja/Desktop/dog_breed/train/000bec180eb18c7604dcecc8fe0dba07.jpg'
img = Image.open(url)
# h = np.array(img)
# img =smp.toimage(url).convert('LA')

# gray = (img.convert('L'))
h = np.array(img)
h.shape
# resizeimage.resize_crop(img, [200, 200])
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x10C6B9198>

# %%
url= '/Users/hardiktaneja/Desktop/dog_breed/train/0159b6457aac89f43d1c1931cdf7500b.jpg'
img = Image.open(url)
# h = np.array(img)
# img =smp.toimage(url).convert('LA')

# gray = (img.convert('L'))
h = np.array(img)
h.shape
imgl = resizeimage.resize_cover(img, [200, 100])
np.array(imgl).shape
# Out:
# (100, 200, 3)

# %%
imgarrgray=[]
targetarrgray=[]
for j in filepaths1:
    root_dir = j
    if(j == '/Users/hardiktaneja/Desktop/dog_breed/train/.DS_Store'):
        continue
    img = Image.open(j)
    h = np.array(img)
#     s = h.shape
    img =smp.toimage(a).convert('LA')
    imgarr.append(s)
#     m =int(j.split('/')[len(j.split('/'))-1].split('_')[1])
#     targetarr.append(m)
# Out:
# list

# %%
df = pd.read_csv("/Users/hardiktaneja/Desktop/dog_breed/labels.csv")

# %%
df[0159b6457aac89f43d1c1931cdf7500b]
# Out:
#   File "<ipython-input-46-2d462b69889f>", line 1
#     df[0159b6457aac89f43d1c1931cdf7500b]
#           ^
# SyntaxError: invalid token

# %%
imgarr_resised=[]
targetarr_resised=[]
