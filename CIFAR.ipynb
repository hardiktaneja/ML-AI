# %%
import sklearn
import sklearn.datasets
import sklearn.tree
import matplotlib.pyplot as plt
import sklearn.linear_model
import pandas as pd
import numpy as np
import sklearn.ensemble
import pylab as pl
import pickle
import scipy.misc as smp

# %%
import sklearn.svm

# %%
with open("/Users/hardiktaneja/Desktop/cifar-100-python/train",'rb') as fo:
    dict = pickle.load(fo, encoding='latin1')

# %%
dict["data"].shape
# Out:
# (50000, 3072)

# %%
x = np.array(dict["data"])

# %%
# img=np.transpose(np.reshape(x[7],(3,32,32)))
img=(np.reshape(x[7],(3,32,32)))

# %%
img.shape
# Out:
# (3, 32, 32)

# %%
img =smp.toimage(img).convert('LA')
img.show()

# %%
type(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e3302af182de> in <module>()
# ----> 1 type(img)
#
# NameError: name 'img' is not defined

# %%
dict.keys()
# Out:
# dict_keys(['filenames', 'batch_label', 'fine_labels', 'coarse_labels', 'data'])

# %%
dict["data"].shape
# Out:
# (50000, 3072)

# %%
dict
# Out:
# {'batch_label': 'training batch 1 of 1',
#  'coarse_labels': [11,
#   15,
#   4,
#   14,
#   1,
#   5,
#   18,
#   3,
#   10,
#   11,
#   5,
#   17,
#   2,
#   9,
#   10,
#   5,
#   18,
#   8,
#   16,
#   10,
#   16,
#   17,
#   2,
#   5,
#   17,
#   6,
#   12,
#   17,
#   8,
#   12,
#   18,
#   9,
#   17,
#   16,
#   11,
#   5,
#   19,
#   14,
#   7,
#   6,
#   15,
#   13,
#   10,
#   8,
#   17,
#   9,
#   14,
#   18,
#   19,
#   15,
#   1,
#   7,
#   5,
#   3,
#   10,
#   7,
#   17,
#   6,
#   14,
#   17,
#   16,
#   0,
#   0,
#   8,
#   4,
#   14,
#   4,
#   10,
#   15,
#   4,
#   2,
#   16,
#   11,
#   19,
#   16,
#   7,
#   19,
#   14,
#   10,
#   8,
#   5,
#   12,
#   12,
#   11,
#   10,
#   8,
#   12,
#   13,
#   10,
#   7,
#   14,
#   11,
#   14,
#   19,
#   0,
#   4,
#   12,
#   13,
#   1,
#   15,
#   0,
#   5,
#   0,
#   8,
#   3,
#   15,
#   4,
#   19,
#   17,
#   6,
#   17,
#   12,
#   6,
#   0,
#   14,
#   10,
#   9,
#   11,
#   6,
#   10,
#   12,
#   1,
#   14,
#   4,
# ...

# %%
type(dict["coarse_labels"])
# Out:
# list

# %%
type(dict["fine_labels"])
# Out:
# list

# %%
x = np.array(dict['data'])
y = np.array(dict['coarse_labels'])

# %%
x_train,x_test,y_train,y_test = sklearn.model_selection.train_test_split(x,y,test_size=.2)

# %%
clf = sklearn.ensemble.RandomForestClassifier(random_state=0)

# %%
clf.fit(x_train,y_train)
clf.score(x_test,y_test)
# Out:
# 0.2316

# %%
model = sklearn.svm.SVC()
model.fit(x_train,y_train)
model.score(x_test,y_test)
