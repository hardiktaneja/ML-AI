# %%
import numpy as np

import matplotlib.pyplot as plt


x = ["Label1","Label2","Label3"]

y = [1,2,3]


plt.plot(x,y)

plt.show() #

plt.savefig('graph1.png')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-06e5758ee409> in <module>()
# ----> 1 print(graph1.png)
#
# NameError: name 'graph1' is not defined

# %%
import numpy as np

import matplotlib.pyplot as plt


# x = ["Label1","Label2","Label3"]
x=range(1,4)

y = [1,2,3]


plt.plot(x,y)

plt.show() #

plt.savefig('graph1.png')

# %%
x = [1,1,1,1,1,2,3]


plt.hist(x)

plt.show()

plt.savefig('graph1.png')
