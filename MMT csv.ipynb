# %%
mmt1  = open("/Users/hardiktaneja/Downloads/makemytrip_com-travel_sample.csv","r")

# %%
mmt = mmt1.readlines()

# %%
print(mmt)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
for i in range(len(mmt[1].split(','))):
    print(i)
    print(mmt[1].split(',')[i])
# Out:
# 0
# Hardasji Ki Magri
# 1
# Udaipur
# 2
# India
# 3
# 2016-06-21
# 4
# {{facility}}
# 5
# "|Zion Home Stay is located in a city that sets around a series of artificial lakes and known for its lavish palaces
# 6
#  Udaipur. The property is situated 25 km from Maharana Pratap Airport
# 7
#  5.2 km from Udaipur Railway Station and Roadways Bus Stand is 5 km away.|Famous excursions guests can visit in Udaipur are Jagadish Temple(2 km)
# 8
#  City Palace(2.2 km)
# 9
#  Moti Magri(3 km)
# 10
#  Fateh Sagar Lake(3.3 km)
# 11
#  Gulab Bagh Zoo(4 km)
# 12
#  Lake Pichola(3.3 km)
# 13
#  Saheliyon Ki Bari(4.2 km)
# 14
#  Shiv Niwas Palace(3.5km)
# 15
#  Taj Lake Palace(3.5 km) and many other.|The property offers facilities that makes the stay of the guests comfortable and relaxing.  Some of the services offered here are room service
# 16
#  parking
# 17
# ...

# %%
print(mmt[0].split(','))
# Out:
# ['area', 'city', 'country', 'crawl_date', 'highlight_value', 'hotel_overview', 'hotel_star_rating', 'image_urls', 'in_your_room', 'is_value_plus', 'latitude', 'longitude', 'mmt_holidayiq_review_count', 'mmt_location_rating', 'mmt_review_count', 'mmt_review_rating', 'mmt_review_score', 'mmt_traveller_type_review_count', 'mmt_tripadvisor_count', 'pageurl', 'property_address', 'property_id', 'property_name', 'property_type', 'qts', 'query_time_stamp', 'room_types', 'site_review_count', 'site_review_rating', 'sitename', 'state', 'traveller_rating', 'uniq_id\n']

# %%
for i in range(len(mmt[2].split(','))):
    print(i)
    print(mmt[2].split(',')[i])
# Out:
# 0
# Near Nai Gaon
# 1
# Udaipur
# 2
# India
# 3
# 2016-06-21
# 4
# {{facility}}
# 5
# "| Araliayas Resorts is a 3 star hotel located amidst mountains of Aravali. It is situated 33.3 km from Udaipur Airport
# 6
#  12.2 km from Udaipur City Railway Station and 11.6 km from bus stop.| Guests can visit famous excursions located near to the property like Lake Pichola(9 km)
# 7
#  City Palace(9.5 km)
# 8
#  Fateh Sagar Lake(10.5 km) and Sajjan Garh(11.3 km).| All rooms of the property are well-equipped and furnished with modern amenities like satellite television
# 9
#  intercom facility
# 10
#  tea/coffee maker
# 11
#  daily newspaper(on request)
# 12
#  Wi-Fi
# 13
#  mini bar
# 14
#  mineral water and room heater(on request).| Araliayas Resorts facilitates services like parking facility
# 15
#  transfers
# 16
#  Wi-Fi
# 17
# ...

# %%
print(mmt[4].split(',')[len(mmt[4].split(','))-5])
# Out:
# ""

# %%
print(mmt[1].split(','))
# Out:
# ['Hardasji Ki Magri', 'Udaipur', 'India', '2016-06-21', '{{facility}}', '"|Zion Home Stay is located in a city that sets around a series of artificial lakes and known for its lavish palaces', ' Udaipur. The property is situated 25 km from Maharana Pratap Airport', ' 5.2 km from Udaipur Railway Station and Roadways Bus Stand is 5 km away.|Famous excursions guests can visit in Udaipur are Jagadish Temple(2 km)', ' City Palace(2.2 km)', ' Moti Magri(3 km)', ' Fateh Sagar Lake(3.3 km)', ' Gulab Bagh Zoo(4 km)', ' Lake Pichola(3.3 km)', ' Saheliyon Ki Bari(4.2 km)', ' Shiv Niwas Palace(3.5km)', ' Taj Lake Palace(3.5 km) and many other.|The property offers facilities that makes the stay of the guests comfortable and relaxing. \xa0Some of the services offered here are room service', ' parking', ' Internet access and laundry service. Guests can avail the facility of doctor on call in case of any medical emergency. The rooms in the hotel are well-maintained', ' ventilated and clean', ' and co
# ...

# %%
mmt1.close()

# %%
biglist2=[]

# %%
for i in range(len(mmt)):
#   print(len(mmt[i].split(',')))
    print(mmt[i].split(',')[len(mmt[i].split(','))-11])
    biglist2.append(mmt[i].split(',')[len(mmt[i].split(','))-11])
# Out:
# property_name
# Zion Home Stay
# Araliayas Resorts
# Shri Udai Palace
# SNP House Airport Hotel And Restaurant
# Hotel Pichola Haveli (LAKE SIDE)
# Garden Hotel
# Jagmandir Island Palace
# Shikarbadi Heritage
# Shiv Niwas Palace
# Hotel The Archi
# Everest Resort
# Hotel Mukund Villas
# Hotel Paras
# Hotel Jagat Villa
# Shree Narayana
# Hotel Sunder
# Blue Mountain Hotel
# Hotel Shalimar Palace
# Amantra Shilpi Resort
# Hotel Kalika Palace
# The Royal Inn
# The Amargarh Resort
# Janak Niwas Guest House
# Adarsh Resort Udaipur
# Le Roi Udaipur
# Udai Haveli Guest House
# Hotel Suman Palace
# RAJ MAHAL RESORT
# New Adarsh Annexe
# Luxor Park
# Hotel Ajanta Haveli
# Hotel PikNik
# The Kensar Homestay
# Hotel Vasundhra
# Hotel Grand Riviera
# Hotel 17 Miles
# Pratap Resort
# Sayoojyam Residency
# Hotel Woodlands
# Hotel Castle View
# Snow Line
# Hotel Neelkamal
# Holiday Heaven
# The Samilton
# Amblee Holiday Resort
# The Aruvi Resort
# Winter Casa Resort
# Hotel Dogra Residency
# ...

# %%
print(mmt[6202].split(',')[len(mmt[6202].split(','))-11])
# Out:
#  Pune"

# %%
print(mmt[1].split(',')[len(mmt[1].split(','))-13])
# Out:
#  Hardasji Ki Magri"

# %%
for i in range(len(mmt[1].split(','))-12,0,-1):
    print(type(mmt[1].split(',')[i]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
import sys

# %%
def ereturn(num):
    try:
        return(int(num))
    except :
    
        return(sys.exc_info()[0])

ans= ereturn("2")

print(ans)
# Out:
# 2

# %%
mmt[1].split(',')[32]
# Out:
# '6'

# %%
for i in range(len(mmt[1].split(','))-13,0,-1):
    tst = ereturn(mmt[1].split(',')[i])
    if(type(tst)==int):
        break

print(i)
# Out:
# 32

# %%
print((mmt)[1])
# Out:
# Hardasji Ki Magri,Udaipur,India,2016-06-21,{{facility}},"|Zion Home Stay is located in a city that sets around a series of artificial lakes and known for its lavish palaces, Udaipur. The property is situated 25 km from Maharana Pratap Airport, 5.2 km from Udaipur Railway Station and Roadways Bus Stand is 5 km away.|Famous excursions guests can visit in Udaipur are Jagadish Temple(2 km), City Palace(2.2 km), Moti Magri(3 km), Fateh Sagar Lake(3.3 km), Gulab Bagh Zoo(4 km), Lake Pichola(3.3 km), Saheliyon Ki Bari(4.2 km), Shiv Niwas Palace(3.5km), Taj Lake Palace(3.5 km) and many other.|The property offers facilities that makes the stay of the guests comfortable and relaxing.  Some of the services offered here are room service, parking, Internet access and laundry service. Guests can avail the facility of doctor on call in case of any medical emergency. The rooms in the hotel are well-maintained, ventilated and clean, and come with good quality furniture. Rooms are fitted with amenitie
# ...

# %%
indexlist=[]
for j in range(len(mmt)):
    for i in range(len(mmt[j].split(','))-13,0,-1):
        tst = ereturn(mmt[j].split(',')[i])
        if(type(tst)==int):
            break
    indexlist.append(i)

# %%
print(type(mmt[2].split(',')[indexlist[1]]))
# Out:
# <class 'str'>

# %%
type(ereturn(mmt[0].split(',')[indexlist[0]])) != int
# Out:
# True

# %%
print(indexlist[0])
# Out:
# 0

# %%
for i in range(len(indexlist)):
    if(type(ereturn(mmt[i].split(',')[indexlist[i]])) != int):
        indexlist[i] = 0

# %%
newlist=[]

# %%
for j in range(len(mmt)):
    i=indexlist[j]
    if(i==0):
        newlist.append("no value here")
    else:
        newlist.append((mmt[j].split(',')[i]))

# %%
for j in range(len(mmt)):
    i=indexlist[j]
    if(type(ereturn(mmt[i].split(',')[indexlist[i]])) != int):
        (ereturn(mmt[i].split(',')[indexlist[i]])) = 0
        
    else:
        print((mmt[j].split(',')[i]))

# %%
for j in range(len(mmt)):
    i=indexlist[j]
    if(type(ereturn(mmt[i].split(',')[indexlist[i]])) != int):
        print("no value here")
    else:
        print((mmt[j].split(',')[i]))
# Out:
# no value here
# 6
# 34
# 16
# 3
# 139
# 79
# 92
# 176
# 344
# 12
# no value here
# 33
# no value here
# 43
# 46
# no value here
# 1
# 16
# 134
# 23
# 21
# 110
# 44
# 3
# 39
# 259
# 0
# 1
# 3
# 4
# 40
# 2
# 0
# 1
# 13
# 45
# 1
# 38
# 26
# 2
# 63
# 3
# 115
# 71
# 58
# 115
# 1
# 0
# 2
# 3
#  10663
# 0
# 1
# 31
# 8
# 14
# 153
# 1
# 1
# 404
# 1
# 27
# 1
# 1
# 1
# 157
# 93
# 97
# 4
# 3
# 1
# 4
# 2
# 118
# 1
# 43
# 1
# 56
# 0
# 221
# 0
# 316
# 0
# 0
# 215
# 31
# 0
# 90
# no value here
# 4
# 0
# 0
# 0
# 0
# 9
# 0
# 3
# 0
# 35
# 37
# no value here
# 16
# 300
# 34
# 4
# 23
# 12
# 3
# 0
# 25
# 6
# 1
# 0
# 22
# 4
# 0
# 71
# 0
# 41
# 6
# 6
# 0
# 14
# 0
# 0
# 8
# 33
# 0
# 6
# 0
# 19
# 0
# 0
# 0
# 5
# 0
# 0
# 56
# 0
# no value here
# 5
# 38
# 15
# 5
# 1
# 0
# 0
# 0
# 0
# 0
# 0
# 14
# 34
# 6
# 1
# 0
# 16
# 128
# 0
# 41
# 0
# 47
# 3
# 4
# 0
# 0
# 0
# 2
# 67
# 92
# 20
# 19
# 3
# 0
# 2
# 0
# 0
# 185
# 0
# 78
# 9
# 11
# 78
# 97
# 12
# 3
# 0
# 4
# 4
# 16
# 0
# no value here
# 0
# 57
# 15
# 0
# 56
# 0
# ...

# %%
#City Wise Top 3
biglist1=[]
biglist2=[]
for j in range(len(mmt)):
    list1=[]
    list2=[]
    list3=[]
        list2.append(cityname)
    biglist1.extend(list1)
    biglist2.extend(list2)
    biglist3.extend(list3)

# %%
biglist1=[]
biglist2=[]
for j in range(len(mmt)):
    i=indexlist[j]
    if(type(ereturn(mmt[i].split(',')[indexlist[i]])) != int):
        biglist1.append(0)
    else:
        biglist1.append(int(mmt[j].split(',')[i]))

# %%
print(biglist1)
# Out:
# [0, 6, 34, 16, 3, 139, 79, 92, 176, 344, 12, 0, 33, 0, 43, 46, 0, 1, 16, 134, 23, 21, 110, 44, 3, 39, 259, 0, 1, 3, 4, 40, 2, 0, 1, 13, 45, 1, 38, 26, 2, 63, 3, 115, 71, 58, 115, 1, 0, 2, 3, 10663, 0, 1, 31, 8, 14, 153, 1, 1, 404, 1, 27, 1, 1, 1, 157, 93, 97, 4, 3, 1, 4, 2, 118, 1, 43, 1, 56, 0, 221, 0, 316, 0, 0, 215, 31, 0, 90, 0, 4, 0, 0, 0, 0, 9, 0, 3, 0, 35, 37, 0, 16, 300, 34, 4, 23, 12, 3, 0, 25, 6, 1, 0, 22, 4, 0, 71, 0, 41, 6, 6, 0, 14, 0, 0, 8, 33, 0, 6, 0, 19, 0, 0, 0, 5, 0, 0, 56, 0, 0, 5, 38, 15, 5, 1, 0, 0, 0, 0, 0, 0, 14, 34, 6, 1, 0, 16, 128, 0, 41, 0, 47, 3, 4, 0, 0, 0, 2, 67, 92, 20, 19, 3, 0, 2, 0, 0, 185, 0, 78, 9, 11, 78, 97, 12, 3, 0, 4, 4, 16, 0, 0, 0, 57, 15, 0, 56, 0, 0, 1, 16, 21, 0, 0, 91, 14, 1, 83, 0, 116, 62, 62, 0, 815, 0, 37, 272, 0, 0, 138, 2, 31, 33, 0, 0, 0, 0, 7, 0, 0, 5, 0, 0, 0, 1, 0, 117, 5, 376, 0, 132, 0, 7, 0, 0, 0, 28, 47, 0, 114, 2, 24, 0, 0, 74, 22, 3, 478, 45, 3, 2, 226, 7, 1, 23, 0, 26, 17, 54, 0, 0, 0, 203, 38, 0, 639, 4, 75, 1, 3, 27, 
# ...

# %%
print(biglist2)
# Out:
# []

# %%
bigtuple=list(zip(biglist1, biglist2))

# %%
print(bigtuple)
# Out:
# [(0, 'property_name'), (6, 'Zion Home Stay'), (34, 'Araliayas Resorts'), (16, 'Shri Udai Palace'), (3, 'SNP House Airport Hotel And Restaurant'), (139, 'Hotel Pichola Haveli (LAKE SIDE)'), (79, 'Garden Hotel'), (92, 'Jagmandir Island Palace'), (176, 'Shikarbadi Heritage'), (344, 'Shiv Niwas Palace'), (12, 'Hotel The Archi'), (0, 'Everest Resort'), (33, 'Hotel Mukund Villas'), (0, 'Hotel Paras'), (43, 'Hotel Jagat Villa'), (46, 'Shree Narayana'), (0, 'Hotel Sunder'), (1, 'Blue Mountain Hotel'), (16, 'Hotel Shalimar Palace'), (134, 'Amantra Shilpi Resort'), (23, 'Hotel Kalika Palace'), (21, 'The Royal Inn'), (110, 'The Amargarh Resort'), (44, 'Janak Niwas Guest House'), (3, 'Adarsh Resort Udaipur'), (39, 'Le Roi Udaipur'), (259, 'Udai Haveli Guest House'), (0, 'Hotel Suman Palace'), (1, 'RAJ MAHAL RESORT'), (3, 'New Adarsh Annexe'), (4, 'Luxor Park'), (40, 'Hotel Ajanta Haveli'), (2, 'Hotel PikNik'), (0, 'The Kensar Homestay'), (1, 'Hotel Vasundhra'), (13, 'Hotel Grand Riviera'), (45, 
# ...

# %%
sortedbiglist=sorted(bigtuple, reverse=True)

# %%
print(sortedbiglist[:10])
# Out:
# [(201603041049551395, ' Pune"'), (201601211932019589, ' Pune"'), (201512221233403186, 'Kukatpally"'), (201512150203385744, ' Andheri (W)"'), (201512150203353131, ' Andheri (W)"'), (201512011307112406, ' Ltd"'), (201511041345358323, ' A Ste..."'), (201510231628541236, ' Ambernath"'), (201509111452156957, 'Hotel'), (201509061937092510, ' Alibaug"')]
