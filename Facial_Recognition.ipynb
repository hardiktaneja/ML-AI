# %%
import pandas as pd

# %%
import numpy as np

# %%
from PIL import Image

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/hardiktaneja/Desktop/facial_keypoints/training.csv")

# %%
df
# Out:
#       left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0             66.033564          39.002274           30.227008
# 1             64.332936          34.970077           29.949277
# 2             65.057053          34.909642           30.903789
# 3             65.225739          37.261774           32.023096
# 4             66.725301          39.621261           32.244810
# 5             69.680748          39.968748           29.183551
# 6             64.131866          34.290040           29.578953
# 7             67.468893          39.413452           29.355961
# 8             65.802880          34.755200           27.475840
# 9             64.121231          36.740308           29.468923
# 10            65.230189          34.342642           28.802717
# 11            66.737600          39.886400           30.270400
# 12            66.574737          37.308000           30.445263
# 13            65.270588          34.940235           33.022745
# ...

# %%
df.keys()
# Out:
# Index(['left_eye_center_x', 'left_eye_center_y', 'right_eye_center_x',
#        'right_eye_center_y', 'left_eye_inner_corner_x',
#        'left_eye_inner_corner_y', 'left_eye_outer_corner_x',
#        'left_eye_outer_corner_y', 'right_eye_inner_corner_x',
#        'right_eye_inner_corner_y', 'right_eye_outer_corner_x',
#        'right_eye_outer_corner_y', 'left_eyebrow_inner_end_x',
#        'left_eyebrow_inner_end_y', 'left_eyebrow_outer_end_x',
#        'left_eyebrow_outer_end_y', 'right_eyebrow_inner_end_x',
#        'right_eyebrow_inner_end_y', 'right_eyebrow_outer_end_x',
#        'right_eyebrow_outer_end_y', 'nose_tip_x', 'nose_tip_y',
#        'mouth_left_corner_x', 'mouth_left_corner_y', 'mouth_right_corner_x',
#        'mouth_right_corner_y', 'mouth_center_top_lip_x',
#        'mouth_center_top_lip_y', 'mouth_center_bottom_lip_x',
#        'mouth_center_bottom_lip_y', 'Image'],
#       dtype='object')

# %%
len(df["Image"][0])
# Out:
# 33593

# %%
len(df["Image"][1])
# Out:
# 32691

# %%
bits = df["Image"][1].split(' ')

# %%
im=np.array(bits).reshape(96,96)

# %%
import scipy.misc as smp

# %%
img = df['Image'][0]

# %%
bits = df["Image"][34].split(' ')
im=np.array(bits,float).reshape(96,96)

# %%
img = Image.fromarray(im)
img.show()

# %%
len(bits)
y = np.arange(0,9216)

# %%
x=[]
y=[]
ht = df.drop(["Image"],axis=1)

# %%
ht.columns
# Out:
# Index(['left_eye_center_x', 'left_eye_center_y', 'right_eye_center_x',
#        'right_eye_center_y', 'left_eye_inner_corner_x',
#        'left_eye_inner_corner_y', 'left_eye_outer_corner_x',
#        'left_eye_outer_corner_y', 'right_eye_inner_corner_x',
#        'right_eye_inner_corner_y', 'right_eye_outer_corner_x',
#        'right_eye_outer_corner_y', 'left_eyebrow_inner_end_x',
#        'left_eyebrow_inner_end_y', 'left_eyebrow_outer_end_x',
#        'left_eyebrow_outer_end_y', 'right_eyebrow_inner_end_x',
#        'right_eyebrow_inner_end_y', 'right_eyebrow_outer_end_x',
#        'right_eyebrow_outer_end_y', 'nose_tip_x', 'nose_tip_y',
#        'mouth_left_corner_x', 'mouth_left_corner_y', 'mouth_right_corner_x',
#        'mouth_right_corner_y', 'mouth_center_top_lip_x',
#        'mouth_center_top_lip_y', 'mouth_center_bottom_lip_x',
#        'mouth_center_bottom_lip_y'],
#       dtype='object')

# %%
ht[ht.columns[0]][0]
# Out:
# 66.033563909799994

# %%
x=[]
y=[]
for i in range(0,len(ht.columns)):
    if(i%2 == 0):
        x.append(ht[ht.columns[i]][34])
    else:
        y.append(ht[ht.columns[i]][34])

# %%
len(x)
# Out:
# 15

# %%
len(ht.columns)
# Out:
# 30

# %%
plt.imshow(img)
# plt.plot(x,y)
plt.scatter(x,y)
plt.show()

# %%
for i in range()

# %%
estimator = tf.estimatorDNNRegressor(feature_columns= feature_columns,hidden_units=[10,10])
