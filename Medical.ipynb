# %%
import pandas as pd
import matplotlib.pyplot as plt
x = pd.read_csv("/Users/hardiktaneja/Documents/diabetes.csv")

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
x.shape
# Out:
# (768, 9)

# %%
preg = x["Pregnancies"]

# %%
preg
# Out:
# 0       6
# 1       1
# 2       8
# 3       1
# 4       0
# 5       5
# 6       3
# 7      10
# 8       2
# 9       8
# 10      4
# 11     10
# 12     10
# 13      1
# 14      5
# 15      7
# 16      0
# 17      7
# 18      1
# 19      1
# 20      3
# 21      8
# 22      7
# 23      9
# 24     11
# 25     10
# 26      7
# 27      1
# 28     13
# 29      5
#        ..
# 738     2
# 739     1
# 740    11
# 741     3
# 742     1
# 743     9
# 744    13
# 745    12
# 746     1
# 747     1
# 748     3
# 749     6
# 750     4
# 751     1
# 752     3
# 753     0
# 754     8
# 755     1
# 756     7
# 757     0
# 758     1
# 759     6
# 760     2
# 761     9
# 762     9
# 763    10
# 764     2
# 765     5
# 766     1
# 767     1
# Name: Pregnancies, Length: 768, dtype: int64

# %%
outcome = x["Outcome"]

# %%
outcome[1]
# Out:
# 0

# %%
preglist=[]

# %%
for i in range(len(preg)):
    if(outcome[i] == 1 ):
        preglist.append(preg[i])

# %%
plt.hist(preglist,bins=100)
plt.show()

# %%
glucose = x["Glucose"]

# %%
gluclist=[]

# %%
for i in range(len(glucose)):
    if(outcome[i]==1):
        gluclist.append(glucose[i])

# %%
plt.hist(gluclist,bins=100)
plt.show()

# %%
bp=x["BloodPressure"]

# %%
bplist=[]

# %%
for i in range(len(outcome)):
    if(outcome[i] == 1):
        bplist.append(bp[i])
plt.hist(bplist,bins=100)
plt.show()

# %%
skin = x["SkinThickness"]
skinlist=[]

# %%
for i in range(len(outcome)):
    if(outcome[i] == 1):
        skinlist.append(skin[i])
plt.hist(skinlist,bins=100)
plt.show()

# %%
insulin=x["Insulin"]
insulinlist=[]

# %%
for i in range(len(outcome)):
    if(outcome[i] == 1):
        insulinlist.append(insulin[i])
plt.hist(insulinlist,bins=100)
plt.show()

# %%
bmi=x["BMI"]
bmilist=[]

# %%
for i in range(len(outcome)):
    if(outcome[i] == 1):
        bmilist.append(bmi[i])
plt.hist(bmilist,bins=100)
plt.show()

# %%
dpf=x["DiabetesPedigreeFunction"]
dpflist=[]

# %%
for i in range(len(outcome)):
    if(outcome[i] == 1):
        dpflist.append(dpf[i])
plt.hist(dpflist,bins=100)
plt.show()

# %%
age=x["Age"]
agelist=[]

# %%
for i in range(len(outcome)):
    if(outcome[i] == 1):
        agelist.append(age[i])
plt.hist(agelist,bins=100)
plt.show()
